# %% [markdown]
# mettre dans le mail: m2ds_lab1_names

# %% [markdown]
# TODO: 1 methods with drift and 1 method adaptiv

# %% [markdown]
# use river / capimova $\newline$
# install rivercopy paste some basic fct and apply it  $\newline$
# Select five method $\newline$
# ex : unsupervised learning : choisir les bons DS qui vont avec et faire les 3 lignes de codes (choisir le bon dataset)$\newline$
# puis faire quelques comparaisons et commentaires : $\newline$
# - Time
# - Accuracy
# - et expliquer pourquoi l'un est plus rapide que l'autre

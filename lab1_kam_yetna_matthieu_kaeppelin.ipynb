# %% [markdown]
# ## M2DS - Data Stream Processing lab 1 : Exploration de River et CAPYMOA
# #### (Kam) Osiris YETNA & Mathieu Kaeppelin

# %% [markdown]
# ### Comparaison sur 2 thèmes : Anomaly Detection et Clustering

# %%
import numpy as np
import pandas as pd
from time import time
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, adjusted_rand_score

# %% [markdown]
# ### Import River

# %%
from river import datasets as river_datasets
from river import metrics as river_metrics
from river import stream

# Anomaly Detection - River
from river.anomaly import HalfSpaceTrees, OneClassSVM
from river.preprocessing import StandardScaler
from river.compose import Pipeline

# Clustering - River  
from river.cluster import DBSTREAM, CluStream, DenStream, STREAMKMeans

# Drift Detection - River
from river.drift import ADWIN, KSWIN

# %%
from river import datasets as river_datasets
from river import metrics as river_metrics
from river import stream

# Anomaly detection 
from river.anomaly import HalfSpaceTrees, OneClassSVM
from river.preprocessing import StandardScaler
from river.compose import Pipeline

# Clustering
from river.cluster import DBSTREAM, CluStream, DenStream, STREAMKMeans

# Drift Detection
from river.drift import ADWIN, KSWIN

# Datasets
phishing_data = river_datasets.Phishing()   # Classification
creditcard_data  = river_datasets.CreditCard() # Anomaly detection
bananas_data   = river_datasets.Bananas()    # Flux multiclass

# %% [markdown]
# ### Import CAPYMOA

# %%
from capymoa.datasets import Electricity, CreditCard, Covertype
from capymoa.evaluation import prequential_evaluation
from capymoa.classifier import HoeffdingTree, AdaptiveRandomForest, OnlineBagging
from capymoa.stream import Stream
from capymoa.drift import ADWIN as CapyADWIN
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from capymoa.datasets import Electricity, CreditCard, Covertype
#       2 from capymoa.evaluation import prequential_evaluation
#       3 from capymoa.classifier import HoeffdingTree, AdaptiveRandomForest, OnlineBagging
#
# ModuleNotFoundError: No module named 'capymoa.datasets'

# %% [markdown]
# ## 1 - Anomaly Detection

# %%
import capymoa
import river

# %% [markdown]
# ### A - River
